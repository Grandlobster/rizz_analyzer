# %%
#hi this is rizz calculation
# !pip install textblob
# Out:
# ...
#   Using cached textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# ...
# Using cached textblob-0.18.0.post0-py3-none-any.whl (626 kB)
# ...

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from textblob import TextBlob

# Load the Excel file
file_path = r'C:\Users\Aadesh\Documents\Study\SEM 5\ExcelFiles\riya_17863957523978417.xlsx'

# Read the Excel data
df = pd.read_excel(file_path)

# Prompt user for the name of the girl
girls_name = input("Enter her name: ")

# Convert the 'date' column to datetime with specified format
df['date'] = pd.to_datetime(df['date'], format='%b %d, %Y, %I:%M %p', errors='coerce')

# Sort the DataFrame by the date column
df = df.sort_values(by='date')

# Fill NaN values in 'content' column with empty strings
df['content'] = df['content'].fillna('')

# Calculate the average string length of all messages sent by Aadesh
aadesh_messages = df[df[girls_name] == 'Aadesh Lawande']
average_aadesh_length = aadesh_messages['content'].apply(len).mean()

# Create a new DataFrame to store the response times
response_times = []

# Loop through the DataFrame to calculate response time for each of your messages
for i in range(len(df) - 1):
    current_row = df.iloc[i]
    next_row = df.iloc[i + 1]

    # Check if the current row is your message and the next row is the response from the girl
    if current_row[gilrs_name] == 'Aadesh Lawande' and next_row[girls_name] == girls_name:
        # Calculate the time difference
        time_diff = next_row['date'] - current_row['date']
        
        # Calculate the length of the response message
        response_length = len(next_row['content'])
        
        # Check if the response length is greater than your average message length
        rizz_bonus_length = 1 if response_length > average_aadesh_length else 0
        
        # Check if the response contains an emoji
        rizz_bonus_emoji = 0  # Set to 0 since we're not checking for emojis
        
        # Perform sentiment analysis on her reply
        reply_sentiment = TextBlob(next_row['content']).sentiment.polarity
        if reply_sentiment > 0:
            sentiment_bonus = 1
        elif reply_sentiment < 0:
            sentiment_bonus = -1
        else:
            sentiment_bonus = 0
        
        # Store the details
        response_times.append({
            'your_message': current_row['content'],
            'response': next_row['content'],
            'response_time': time_diff,
            'response_length': response_length,
            'rizz_bonus_length': rizz_bonus_length,
            'rizz_bonus_emoji': rizz_bonus_emoji,
            'sentiment_bonus': sentiment_bonus
        })

# Convert the response_times list to a DataFrame for easier analysis
response_times_df = pd.DataFrame(response_times)

# Analyze "rizz level"
response_times_df['rizz_level'] = response_times_df.apply(
    lambda row: 'High' if row['response_time'].total_seconds() <= 300 and (row['rizz_bonus_length'] + row['rizz_bonus_emoji'] + row['sentiment_bonus']) >= 1 else 
                'Medium' if row['response_time'].total_seconds() <= 600 and (row['rizz_bonus_length'] + row['rizz_bonus_emoji'] + row['sentiment_bonus']) >= 1 else 
                'Low', axis=1)

# Display the results with the added rizz bonuses
print(response_times_df[['your_message', 'response', 'response_time', 'response_length', 'rizz_bonus_length', 'rizz_bonus_emoji', 'sentiment_bonus', 'rizz_level']])

# Create a line graph of rizz level over time
response_times_df['date'] = pd.to_datetime(response_times_df['response_time'].cumsum() + df['date'].min())

# Plot the graph
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(response_times_df['date'], response_times_df['rizz_level'], linestyle='-', marker='o')

# Set the x-axis tick format to display dates
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d'))

# Rotate the x-axis tick labels for better readability
plt.xticks(rotation=45)

# Set labels and title
ax.set_xlabel('Date')
ax.set_ylabel('Rizz Level')
ax.set_title('Rizz Level Over Time with Sentiment Adjustment')

# Adjust the spacing between subplots
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# Enter her name:  Riya
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Riya'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 26
#      23 df['content'] = df['content'].fillna('')
# ...
